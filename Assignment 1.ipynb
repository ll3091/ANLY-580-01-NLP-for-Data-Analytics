# %% [markdown]
# # NLTK

# %% [markdown]
# Chapter 1 exercises 4, 6, 22-24, 28

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# 4.

# %%
# words in text2
len(text2)
# Out:
# 141576

# %%
# distinct words in text2
len(set(text2))
# Out:
# 6833

# %% [markdown]
# 6.

# %%
# dispersion plot of the four main protagonists in Sense and Sensibility: 
#    Elinor, Marianne, Edward, and Willoughby
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# The females, Elinor and Marianne, appear to be more prominent characters than the males, Edward and Willoughby. Willoughby seems to appear in the text when Marianne does and are therefore likely to be a couple. It is difficult to determine if Elinor is part of a couple because her name appears frequently throughout the text.

# %% [markdown]
# 22.

# %%
# four-letter words from text5 in decreasing order of frequency
four_ltr_words = [w for w in text5 if len(w)==4 and w.isalpha()]
fdist = FreqDist(four_ltr_words)
fdist.most_common()
# Out:
# [('JOIN', 1021),
#  ('PART', 1016),
#  ('that', 274),
#  ('what', 183),
#  ('here', 181),
#  ('have', 164),
#  ('like', 156),
#  ('with', 152),
#  ('chat', 142),
#  ('your', 137),
#  ('good', 130),
#  ('just', 125),
#  ('lmao', 107),
#  ('know', 103),
#  ('room', 98),
#  ('from', 92),
#  ('this', 86),
#  ('well', 81),
#  ('back', 78),
#  ('hiya', 78),
#  ('they', 77),
#  ('dont', 75),
#  ('yeah', 75),
#  ('want', 71),
#  ('love', 60),
#  ('guys', 58),
#  ('some', 58),
#  ('been', 57),
#  ('talk', 56),
#  ('nice', 52),
#  ('time', 50),
#  ('when', 48),
#  ('haha', 44),
#  ('make', 44),
#  ('girl', 43),
#  ('need', 43),
#  ('MODE', 41),
#  ('will', 40),
#  ('much', 40),
#  ('then', 40),
#  ('over', 39),
#  ('work', 38),
#  ('were', 38),
#  ('take', 37),
#  ('song', 36),
#  ('even', 35),
#  ('does', 35),
#  ('seen', 35),
#  ('more', 34),
#  ('damn', 34),
#  ('only', 33),
#  ('come', 33),
#  ('hell', 29),
#  ('long', 28),
#  ('them', 28),
#  ('name', 27),
#  ('tell', 27),
# ...

# %% [markdown]
# 23.

# %%
# uppercase words from text6
for w in text6:
    if w.isupper():
        print(w)
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %% [markdown]
# 24.

# %% [markdown]
# words in *text6* that meet the conditions listed below

# %%
# a. ending in 'ize'
[w for w in text6 if w.endswith('ize')]
# Out:
# []

# %%
# b. containing the letter 'z'
[w for w in text6 if 'z' in w]
# Out:
# ['zone',
#  'amazes',
#  'Fetchez',
#  'Fetchez',
#  'zoop',
#  'zoo',
#  'zhiv',
#  'frozen',
#  'zoosh']

# %%
# c. containing the sequence of letters 'pt'
[w for w in text6 if 'pt' in w]
# Out:
# ['empty',
#  'aptly',
#  'Thpppppt',
#  'Thppt',
#  'Thppt',
#  'empty',
#  'Thppppt',
#  'temptress',
#  'temptation',
#  'ptoo',
#  'Chapter',
#  'excepting',
#  'Thpppt']

# %%
# d. having all lowercase letters except for initial capital
[w for w in text6 if w.istitle()]
# Out:
# ['Whoa',
#  'Halt',
#  'Who',
#  'It',
#  'I',
#  'Arthur',
#  'Uther',
#  'Pendragon',
#  'Camelot',
#  'King',
#  'Britons',
#  'Saxons',
#  'England',
#  'Pull',
#  'I',
#  'Patsy',
#  'We',
#  'Camelot',
#  'I',
#  'What',
#  'Ridden',
#  'Yes',
#  'You',
#  'What',
#  'You',
#  'So',
#  'We',
#  'Mercea',
#  'Where',
#  'We',
#  'Found',
#  'In',
#  'Mercea',
#  'The',
#  'What',
#  'Well',
#  'The',
#  'Are',
#  'Not',
#  'They',
#  'What',
#  'A',
#  'It',
#  'It',
#  'It',
#  'A',
#  'Well',
#  'Will',
#  'Arthur',
#  'Court',
#  'Camelot',
#  'Listen',
#  'In',
#  'Please',
#  'Am',
#  'I',
#  'I',
#  'It',
#  'African',
#  'Oh',
#  'African',
#  'European',
#  'That',
#  'Oh',
#  'I',
#  'Will',
#  'Camelot',
#  'But',
#  'African',
#  'Oh',
#  'So',
#  'Wait',
#  'Supposing',
#  'No',
#  'Well',
#  'They',
#  'What',
#  'Well',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Bring',
#  'Ninepence',
#  'Bring',
#  'Bring',
# ...

# %% [markdown]
# 28.

# %%
# define a function that calculates how often given 
# word occurs in a text & expresses result as percentage
def percent(word, text):
    return 100*text.count(word)/len(text)

# test function
percent('a', text4)
# Out:
# 1.4643016433938312
